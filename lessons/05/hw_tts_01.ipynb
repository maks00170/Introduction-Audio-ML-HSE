# %% [markdown]
# # Основы синтеза речи. Домашняя работа №1

# %% [markdown]
# ## Условия
#
# Время выполнения - 1 неделя

# %% [markdown]
# ## Задание №1 - Синтез (3 балла)
#
# Синтезируйте произвольный текст, используя батчевую обработку. Каждое отдельное предложение синтезируйте как отдельное аудио в батче.

# %% [markdown]
# ## Задание №2 - Визуализация (4 балла)
#
# Визуализируйте как промежуточные, так и итоговые результаты синтеза:
# 1. Мел-спектрограммы
# 2. Attention (выравнивание между тестом и речью)
# 3. Итоговая волновая форма

# %% [markdown]
# ## Задание №3 - Внимание (6 балла)
#
# Соотнесите текстовые токены и выходное аудио используя attention. В результате выведите метки времени для каждого входного токена.
#
# **Подсказка**: в случае с tacotron2 attention дает соответсвие между текстом и мел-спектрограммой. Попробуйте для начала вывести соответствие между бинами мел-спектрограммы и временем у выходного аудио

# %% [markdown]
# ## Задание №4 - Качество (2 балл)
#
# Оцените качество. Для субъективных оценок используйте произвольный пример речи.

# %%
import torch
import torchaudio

from tqdm.auto import tqdm
